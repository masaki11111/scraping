# %%
from selenium import webdriver
import pandas as pd
import time

# %%
driver=webdriver.Chrome()

# %%
driver.get('https://www.ekiten.jp/area/')
path='/html/body/div[2]/div/div[2]/main/div[44]/div/a'
lists=[]
i=6
#サイトURL

# %%
elems=driver.find_elements_by_class_name('p-shop_box')#class名に空白がある場合はどちらか一方を選んであげるとよい
for elem in elems:
    list=[]
    elem_title=elem.find_element_by_class_name('p-shop_box_head_title_body').text
    list.append(elem_title)
    elem_supplement=elem.find_element_by_class_name('p-shop_box_head_supplement').text
    list.append(elem_supplement)
    elem_address=elem.find_element_by_class_name('p-shop_box_basic_info').find_elements_by_class_name('p-shop_box_basic_info_item')[1]
    elem_address=elem_address.text.split('\n')[1]
    list.append(elem_address)
    href = elem.find_element_by_tag_name("a").get_attribute("href")#リンク先のURLの取得方法
    list.append(href)
    lists.append(list)
    
next_page=driver.find_element_by_xpath(path).get_attribute("href")
driver.get(next_page)
driver.implicitly_wait(10)#implicity_wait():指定したドライバに対して引数の時間分（秒）、要素が見つかるまで(ロードされるまで)待機
time.sleep(10)
path="/html/body/div[2]/div/div[2]/main/div[44]/div[2]/a"

while True:
#len(elem)
    elems=driver.find_elements_by_class_name('p-shop_box')#class名に空白がある場合はどちらか一方を選んであげるとよい
    for elem in elems:
        list=[]
        elem_title=elem.find_element_by_class_name('p-shop_box_head_title_body').text
        list.append(elem_title)
        elem_supplement=elem.find_element_by_class_name('p-shop_box_head_supplement').text
        list.append(elem_supplement)
        elem_address=elem.find_element_by_class_name('p-shop_box_basic_info').find_elements_by_class_name('p-shop_box_basic_info_item')[1]
        elem_address=elem_address.text.split('\n')[1]
        list.append(elem_address)
        href = elem.find_element_by_tag_name("a").get_attribute("href")#リンク先のURLの取得方法
        list.append(href)
        lists.append(list)
    lists
    #if len(driver.find_elements_by_xpath(path))>0:
    if i>0:
        next_page=driver.find_element_by_xpath(path).get_attribute("href")
        driver.get(next_page)
        driver.implicitly_wait(10)#implicity_wait():指定したドライバに対して引数の時間分（秒）、要素が見つかるまで(ロードされるまで)待機
        time.sleep(10)
        
        path="/html/body/div[2]/div/div[2]/main/div[44]/div[3]/a"
        i-=1    
    else:
        break
#type('elems')

# %%
df=pd.DataFrame(lists)
df.columns=['店舗名','ジャンル','住所','URL']
df.to_csv('ekiten.csv',encoding="utf_8_sig")#インデックスを消すためにはFalseを
df
# Out:
#                                  店舗名                        ジャンル  \
# 0                姿勢矯正専門院foryou　八戸ノ里院                 接骨・整骨 鍼灸 整体
# 1                         夢の整骨院　八柱分院              マッサージ 整体 接骨・整骨
# 2                         鍼灸整骨院　いやし堂              接骨・整骨 鍼灸 マッサージ
# 3                           ぱんだ鍼灸接骨院       接骨・整骨 鍼灸 健康・美容サービスその他
# 4                              横浜整体院         整体 カイロプラクティック マッサージ
# 5                          富里ひまわり整骨院              接骨・整骨 マッサージ 整体
# 6                  カイロプラクティックセンター　静岡         マッサージ 整体 カイロプラクティック
# 7                    ボディメンテナンス池下　整骨院              接骨・整骨 整体 マッサージ
# 8                        ぷらちな整骨院　戸越院              整体 マッサージ 接骨・整骨
# 9                         整骨院ＫＡＩ-御影院                 接骨・整骨 整体 鍼灸
# 10                     iCure鍼灸接骨院 福島              接骨・整骨 鍼灸 マッサージ
# 11                           竹内鍼灸治療所            カイロプラクティック 鍼灸 整体
# 12                          新所沢骨盤整骨院                 接骨・整骨 整体 鍼灸
# 13                     じん鍼灸整骨院　平松本町院                 整体 接骨・整骨 鍼灸
# 14                          はじめ鍼灸整骨院                 接骨・整骨 整体 鍼灸
# 15                           すこやか整骨院    接骨・整骨 マッサージ 健康・美容サービスその他
# 16                          ふたば鍼灸整骨院                 接骨・整骨 鍼灸 整体
# 17                        たけだ整骨院 北大前                 整体 接骨・整骨 鍼灸
# 18                   戸塚カイロプラクティック整体院               カイロプラクティック 整体
# 19                         笑顔道 登戸整骨院              接骨・整骨 整体 マッサージ
# 20                           ロイヤル整体院                      整体 エステ
# 21                         小岩名倉総武整骨院         カイロプラクティック 接骨・整骨 整体
# 22                           本町駅前整骨院              接骨・整骨 マッサージ 整体
# 23                             優和治療院                 マッサージ 整体 鍼灸
# 24                          桜新町気功整体院         整体 マッサージ カイロプラクティック
# 25                    iCure鍼灸接骨院 心斎橋              接骨・整骨 マッサージ 整体
# 26                      札幌あゆみ整骨院　大通院                 接骨・整骨 鍼灸 整体
# 27                        あすなろ整骨院　布施              接骨・整骨 整体 マッサージ
# 28                       後藤鍼灸整骨院 吉塚院                 接骨・整骨 鍼灸 整体
# 29                        久喜ななつぼし整骨院              マッサージ 整体 接骨・整骨
# ..                               ...                         ...
# 290                           やまと整骨院                 接骨・整骨 鍼灸 整体
# 291                           わかば整骨院              接骨・整骨 マッサージ 整体
# 292                         みかも鍼灸接骨院              整体 マッサージ 接骨・整骨
# 293                  はらだ指圧整体マッサージ治療室                 マッサージ 鍼灸 整体
# 294                         整体Room笑美       整体 マッサージ 健康・美容サービスその他
# 295                       整骨院 絆（きずな）         接骨・整骨 整体 カイロプラクティック
# 296                    めいほく接骨院　名古屋本院              接骨・整骨 整体 マッサージ
# 297                     てあて鍼灸整骨院・整体院                 接骨・整骨 整体 鍼灸
# 298                あかつき鍼灸接骨院　みずほ台　本院              接骨・整骨 鍼灸 マッサージ
# 299                         上本町鍼灸整骨院                 整体 鍼灸 接骨・整骨
# 300  新橋カイロプラクティック整体院　Office YAMAMOTO  カイロプラクティック 整体 健康・美容サービスその他
# 301             カイロプラクティック整体院インフィニティ  カイロプラクティック 整体 健康・美容サービスその他
# 302                           香里園整骨院         接骨・整骨 整体 カイロプラクティック
# 303                          南柏駅前整骨院              接骨・整骨 マッサージ 整体
# 304                         針中野駒川整骨院         接骨・整骨 整体 カイロプラクティック
# 305                      りらく鍼灸接骨院 北院              接骨・整骨 マッサージ 整体
# 306                          梵soyogi       整体 マッサージ 健康・美容サービスその他
# 307                            心笑整骨院              接骨・整骨 整体 マッサージ
# 308                     ミオカイロ練馬駅前整体院         整体 カイロプラクティック マッサージ
# 309                          たどころ整骨院              接骨・整骨 マッサージ 整体
# 310                    笑顔道 スイッチON整骨院                 接骨・整骨 整体 鍼灸
# 311                       あすなろ整骨院 三宮       接骨・整骨 健康・美容サービスその他 整体
# 312                        たてやま鍼灸整骨院              接骨・整骨 整体 マッサージ
# 313                     メディカル・ブルー整骨院              接骨・整骨 整体 マッサージ
# 314                    カイロプラクティックいとう               カイロプラクティック 整体
# 315                    うめみつ鍼灸整骨院・整体院                 接骨・整骨 鍼灸 整体
# 316                    くまのみ整骨院　大宮天沼院              接骨・整骨 整体 マッサージ
# 317                        永田東洋鍼灸整骨院                 接骨・整骨 鍼灸 整体
# 318                         杉並高円寺整骨院         接骨・整骨 整体 カイロプラクティック
# 319                         東洋はり灸整骨院                 鍼灸 接骨・整骨 整体
#
#                                      住所                                   URL
# 0                      大阪府東大阪市下小阪4-6-10   https://www.ekiten.jp/shop_7061390/
# 1           千葉県松戸市日暮2-5-11グリーンプラザ第２ビル１Ｆ   https://www.ekiten.jp/shop_7126262/
# 2         大阪府堺市南区鴨谷台2-1-1アーバンコンフォート202c   https://www.ekiten.jp/shop_6046582/
# 3             大阪府吹田市朝日町2-218吹田さんくす2番館2F   https://www.ekiten.jp/shop_7157488/
# 4            神奈川県横浜市西区岡野1丁目９−６第八Z西村ビル2C   https://www.ekiten.jp/shop_6773832/
# 5                  千葉県富里市七栄323-5 相川ビル１階  https://www.ekiten.jp/shop_48227776/
# 6               静岡県静岡市葵区伝馬町８−１サンローゼビル４Ｆ   https://www.ekiten.jp/shop_1209270/
# 7           愛知県名古屋市千種区池下1丁目2-3LAC池下ビル１F   https://www.ekiten.jp/shop_6891188/
# 8                  東京都品川区戸越２丁目５−５竹中ビル１F   https://www.ekiten.jp/shop_3019057/
# 9               兵庫県神戸市東灘区御影中町1丁目10-8栁ビル   https://www.ekiten.jp/shop_6021322/
# 10                    大阪府大阪市福島区福島5-6-10  https://www.ekiten.jp/shop_97608861/
# 11                    東京都品川区東五反田２丁目５−１１    https://www.ekiten.jp/shop_255056/
# 12                       埼玉県所沢市緑町４−７−１７  https://www.ekiten.jp/shop_66258474/
# 13              栃木県宇都宮市平松本町353-11ドミール平松  https://www.ekiten.jp/shop_67783462/
# 14                        宮崎県宮崎市青葉町74-2  https://www.ekiten.jp/shop_71576380/
# 15                    大阪府大阪市生野区林寺１丁目４−３   https://www.ekiten.jp/shop_6043255/
# 16       京都府京都市中京区西ノ京鹿垣町５−１ラスパルマス京都円町一階   https://www.ekiten.jp/shop_6059184/
# 17                 北海道札幌市北区北１５条西４丁目１−１４   https://www.ekiten.jp/shop_6052278/
# 18             神奈川県横浜市戸塚区戸塚町142鈴木ビル102号   https://www.ekiten.jp/shop_7136859/
# 19        神奈川県川崎市多摩区中野島2325-1いなげや川崎登戸店内   https://www.ekiten.jp/shop_7015756/
# 20           山形県山形市三日町１丁目１−３ロイヤルコーポ蜂屋１Ｆ   https://www.ekiten.jp/shop_2558268/
# 21                    東京都江戸川区西小岩１−１２−１６   https://www.ekiten.jp/shop_6059212/
# 22            大阪府大阪市中央区備後町３丁目３番１号西島ビル3階  https://www.ekiten.jp/shop_59458939/
# 23     神奈川県川崎市中原区新丸子東2-897-11ラポール新丸子209   https://www.ekiten.jp/shop_6023073/
# 24        東京都世田谷区桜新町2-14-2　ヴォワールメゾン204号   https://www.ekiten.jp/shop_2916803/
# 25      大阪府大阪市中央区南船場4-4-8クリエイティブ心斎橋ビル3Ｆ   https://www.ekiten.jp/shop_6993697/
# 26   北海道札幌市中央区南1条西２丁目9−1IKEUCHI ZONE 7F   https://www.ekiten.jp/shop_6993185/
# 27              大阪府東大阪市長堂3-2-22あすなろビル2F    https://www.ekiten.jp/shop_736037/
# 28                    福岡県福岡市博多区吉塚本町１０−８   https://www.ekiten.jp/shop_6920743/
# 29               埼玉県久喜市久喜中央2-9-41TKビル２F   https://www.ekiten.jp/shop_6771576/
# ..                                  ...                                   ...
# 290                  鹿児島県霧島市隼人町見次１３００−２   https://www.ekiten.jp/shop_6743072/
# 291                     東京都江戸川区北小岩2-9-1   https://www.ekiten.jp/shop_6009795/
# 292                        愛知県豊橋市西小池町２３   https://www.ekiten.jp/shop_3808706/
# 293             東京都町田市中町１丁目１６−１３奥村ビル２０４    https://www.ekiten.jp/shop_216574/
# 294             静岡県富士市松岡856-3　タウンハウス中川C   https://www.ekiten.jp/shop_6770728/
# 295                 広島県広島市佐伯区三宅1丁目3番38号  https://www.ekiten.jp/shop_22034062/
# 296                  愛知県名古屋市東区大幸１丁目５−２３    https://www.ekiten.jp/shop_996338/
# 297                       長崎県長崎市目覚町１６−２   https://www.ekiten.jp/shop_6054614/
# 298         埼玉県富士見市東みずほ台2-2-11パールヴィラ1-A   https://www.ekiten.jp/shop_6762797/
# 299                  大阪府大阪市天王寺区東高津町11-3  https://www.ekiten.jp/shop_30085421/
# 300              東京都港区東新橋1-2-10PAL汐留M2F   https://www.ekiten.jp/shop_7016097/
# 301                    静岡県静岡市駿河区用宗2-6-8  https://www.ekiten.jp/shop_31763538/
# 302         大阪府寝屋川市香里南之町32-5YNレジデンス香里1f   https://www.ekiten.jp/shop_6766105/
# 303                  千葉県柏市南柏1-1-6桔梗ビル1F   https://www.ekiten.jp/shop_6009806/
# 304                 大阪府大阪市東住吉区駒川5丁目8番9号   https://www.ekiten.jp/shop_6059958/
# 305        兵庫県尼崎市武庫之荘5-6-2　ハピネス武庫之荘北101   https://www.ekiten.jp/shop_6015246/
# 306           埼玉県さいたま市南区南浦和2-41-19201号室  https://www.ekiten.jp/shop_45825964/
# 307                    大分県大分市金池南１丁目１−１９   https://www.ekiten.jp/shop_6762271/
# 308                東京都練馬区豊玉北5-18-10-902   https://www.ekiten.jp/shop_7137949/
# 309       茨城県水戸市河和田1丁目1535-43リバーシャトー103   https://www.ekiten.jp/shop_3101333/
# 310           東京都渋谷区笹塚1-50-1笹塚NAビル101号室   https://www.ekiten.jp/shop_6893117/
# 311            兵庫県神戸市中央区布引町３丁目２−１布引ビル1Ｆ   https://www.ekiten.jp/shop_1091084/
# 312        大阪府茨木市真砂１丁目９−３１ボー・ドミール南茨木105   https://www.ekiten.jp/shop_3066827/
# 313     神奈川県横浜市保土ケ谷区帷子町2-69メディカル・ブルー整骨院   https://www.ekiten.jp/shop_7138763/
# 314                   東京都八王子市元八王子町1-7-4  https://www.ekiten.jp/shop_24326307/
# 315                    福岡県久留米市梅満町１１２９−４   https://www.ekiten.jp/shop_6877514/
# 316        埼玉県さいたま市大宮区天沼町１−６１５第二進藤ビル102   https://www.ekiten.jp/shop_3156250/
# 317       京都府京都市伏見区東町２１２ツインズスクエア　ウエスト１Ｆ   https://www.ekiten.jp/shop_6041069/
# 318                   東京都杉並区高円寺南3-58-26   https://www.ekiten.jp/shop_7015185/
# 319             東京都町田市森野１−３４−１８ユニオンビル４階   https://www.ekiten.jp/shop_3747704/
#
# [320 rows x 4 columns]
